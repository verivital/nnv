# %%
# Configuration - Docker container paths
BASE_DIR = "/nnv/code/nnv/examples/Submission/FORMALISE2025"
DATA_DIR = f"{BASE_DIR}/data"
MODELS_DIR = f"{BASE_DIR}/models"

# %%
import os
import numpy as np

# %%
data_dir = DATA_DIR

# %% [markdown]
# # Load MNIST

# %%
zoom_in_samples = [751, 137, 34, 878, 328, 289, 262, 168, 871, 126, 796, 877, 645, 108, 693, 501, 44, 41, 117, 257, 272, 597, 707, 37, 661, 237, 845, 763, 830, 645, 498, 259, 532, 692, 331, 972, 8, 904, 966, 193, 826, 501, 407, 331, 187, 254, 908, 402, 126, 116, 452, 121, 429, 411, 709, 317, 969, 57, 863, 543, 636, 150, 450, 99, 652, 350, 999, 736, 724, 432, 680, 230, 833, 90, 61, 780, 267, 922, 346, 100, 272, 125, 452, 331, 537, 744, 435, 198, 442, 423, 248, 790, 320, 830, 806, 761, 92, 714, 744, 207]
zoom_out_samples = [624, 882, 278, 180, 540, 439, 306, 757, 821, 654, 248, 817, 368, 949, 963, 59, 260, 34, 357, 465, 304, 69, 238, 666, 867, 356, 239, 776, 585, 460, 760, 536, 158, 301, 154, 280, 908, 659, 632, 297, 910, 687, 499, 686, 463, 418, 248, 152, 596, 578, 96, 922, 50, 117, 169, 738, 176, 989, 809, 491, 702, 67, 445, 441, 547, 616, 285, 649, 12, 809, 872, 126, 812, 630, 916, 303, 952, 758, 390, 120, 332, 507, 174, 529, 4, 873, 868, 297, 586, 933, 196, 594, 112, 736, 337, 755, 719, 223, 169, 433]

# %%
data = np.load(os.path.join(data_dir, 'ZoomIn', 'test', f'mnistvideo_zoom_in_4f_test_data_seq.npy'))
labels = np.load(os.path.join(data_dir, 'ZoomIn', 'test', f'mnistvideo_zoom_in_test_labels_seq.npy'))

# %%
new_data = data[zoom_in_samples]
new_labels = labels[zoom_in_samples]

# %%
np.save(os.path.join(data_dir, 'verification', 'ZoomIn', 'mnistvideo_zoom_in_4f_test_data_seq.npy'), new_data)
np.save(os.path.join(data_dir, 'verification', 'ZoomIn', 'mnistvideo_zoom_in_test_labels_seq.npy'), new_labels)

# %%
# 8-frame
data = np.load(os.path.join(data_dir, 'ZoomIn', 'test', f'mnistvideo_zoom_in_8f_test_data_seq.npy'))
new_data = data[zoom_in_samples]
np.save(os.path.join(data_dir, 'verification', 'ZoomIn', 'mnistvideo_zoom_in_8f_test_data_seq.npy'), new_data)

# %%
# 16-frame
data = np.load(os.path.join(data_dir, 'ZoomIn', 'test', f'mnistvideo_zoom_in_16f_test_data_seq.npy'))
new_data = data[zoom_in_samples]
np.save(os.path.join(data_dir, 'verification', 'ZoomIn', 'mnistvideo_zoom_in_16f_test_data_seq.npy'), new_data)

# %%
# Zoom Out
data = np.load(os.path.join(data_dir, 'ZoomOut', 'test', f'mnistvideo_zoom_out_4f_test_data_seq.npy'))
labels = np.load(os.path.join(data_dir, 'ZoomOut', 'test', f'mnistvideo_zoom_out_test_labels_seq.npy'))

# %%
new_data = data[zoom_out_samples]
new_labels = data[zoom_out_samples]

# %%
np.save(os.path.join(data_dir, 'verification', 'ZoomOut', 'mnistvideo_zoom_out_4f_test_data_seq.npy'), new_data)
np.save(os.path.join(data_dir, 'verification', 'ZoomOut', 'mnistvideo_zoom_out_test_labels_seq.npy'), new_labels)

# %%
# 8-frame
data = np.load(os.path.join(data_dir, 'ZoomOut', 'test', f'mnistvideo_zoom_out_8f_test_data_seq.npy'))
new_data = data[zoom_out_samples]
np.save(os.path.join(data_dir, 'verification', 'ZoomOut', 'mnistvideo_zoom_out_8f_test_data_seq.npy'), new_data)

# %%
# 16-frame
data = np.load(os.path.join(data_dir, 'ZoomOut', 'test', f'mnistvideo_zoom_out_16f_test_data_seq.npy'))
new_data = data[zoom_out_samples]
np.save(os.path.join(data_dir, 'verification', 'ZoomOut', 'mnistvideo_zoom_out_16f_test_data_seq.npy'), new_data)

# %% [markdown]
# # Load GTSRB

# %%
samples = [12597, 2196, 507, 5423, 4840, 4410, 2743, 2020, 10754, 1707, 11622, 8312, 635, 596, 1851, 4320, 4595, 9948, 11849, 535, 11062, 3942, 10746, 8256, 4356, 8857, 11599, 5483, 127, 3154, 8326, 6696, 5474, 3075, 4256, 6625, 2013, 1832, 7475, 1908, 7068, 6765, 11879, 5214, 858, 9051, 10579, 2459, 7450, 1550, 10884, 5771, 12391, 12180, 7128, 11366, 3809, 1367, 910, 4497, 5706, 1570, 4599, 1989, 7478, 5480, 8937, 12524, 7190, 3209, 7303, 6996, 4143, 5263, 1406, 11985, 12510, 3378, 10534, 4838, 3228, 9106, 7467, 5324, 12607, 10979, 4343, 6387, 1109, 4525, 641, 6208, 7898, 5278, 1302, 4171, 11173, 6190, 4204, 9824, 7788, 9041, 2814, 5221, 2744, 4873, 11065, 10632, 5180, 11510, 8452, 11492, 7863, 7133, 4337, 2721, 10042, 9713, 1796, 935, 2161, 3020, 12365, 3161, 8318, 11739, 1249, 7568, 7504, 11728, 9222, 10436, 4971, 10910, 228, 2253, 10594, 5260, 12629, 6695, 2199, 5778, 8578, 3125, 8944, 61, 5195, 9852, 3527, 10001, 2101, 12318, 5875, 12588, 10001, 11982, 3943, 3020, 7371, 3190, 10639, 10457, 10, 11787, 6384, 9622, 398, 2204, 7152, 6052, 4732, 1147, 4760, 11178, 1549, 1685, 9577, 1358, 10501, 2476, 2531, 9366, 10839, 3267, 5224, 10405, 11933, 8336, 4190, 10637, 3985, 6135, 7857, 7363, 8642, 10196, 8901, 2385, 4901, 4439, 1258, 6656, 427, 11580, 10921, 4549, 11583, 4353, 141, 1398, 12441, 1162, 4523, 1326, 629]

# %%
data = np.load(os.path.join(data_dir, 'GTSRB', 'test', f'gtsrbvideo_4f_test_data_seq.npy'))
labels = np.load(os.path.join(data_dir, 'GTSRB', 'test', f'gtsrbvideo_test_labels_seq.npy'))

# %%
new_data = data[samples]
new_labels = labels[samples]

# %%
np.save(os.path.join(data_dir, 'verification', 'GTSRB', 'gtsrbvideo_4f_test_data_seq.npy'), new_data)
np.save(os.path.join(data_dir, 'verification', 'GTSRB', 'gtsrbvideo_test_labels_seq.npy'), new_labels)

# %%
# 8-frame
data = np.load(os.path.join(data_dir, 'GTSRB', 'test', f'gtsrbvideo_8f_test_data_seq.npy'))
new_data = data[samples]
np.save(os.path.join(data_dir, 'verification', 'GTSRB', 'gtsrbvideo_8f_test_data_seq.npy'), new_data)

# %%
# 16-frame
data = np.load(os.path.join(data_dir, 'GTSRB', 'test', f'gtsrbvideo_16f_test_data_seq.npy'))
new_data = data[samples]
np.save(os.path.join(data_dir, 'verification', 'GTSRB', 'gtsrbvideo_16f_test_data_seq.npy'), new_data)

# %% [markdown]
# # Load STMNIST

# %%
samples = [311, 64, 719, 646, 595, 385, 268, 220, 1090, 77, 75, 237, 568, 616, 1290, 67, 515, 1086, 579, 1162, 725, 14, 425, 1090, 880, 418, 558, 866, 268, 236, 992, 256, 915, 888, 694, 112, 1181, 1378, 344, 989, 197, 763, 932, 499, 171, 117, 603, 758, 200, 616, 267, 992, 725, 1172, 946, 430, 973, 911, 545, 700, 182, 450, 1373, 646, 431, 1187, 990, 709, 573, 841, 139, 605, 77, 821, 1045, 701, 164, 549, 820, 550, 1282, 1029, 1180, 396, 696, 385, 649, 1382, 693, 1106, 1039, 932, 573, 384, 1298, 1267, 234, 120, 298, 413]

# %%
data = np.load(os.path.join(data_dir, 'STMNIST', 'test', f'stmnistvideo_16f_test_data_seq.npy'))
labels = np.load(os.path.join(data_dir, 'STMNIST', 'test', f'stmnistvideo_16f_test_labels_seq.npy'))

# %%
new_data = data[samples]
new_labels = labels[samples]

# %%
np.save(os.path.join(data_dir, 'verification', 'STMNIST', 'stmnistvideo_16f_test_data_seq.npy'), new_data)
np.save(os.path.join(data_dir, 'verification', 'STMNIST', 'stmnistvideo_16f_test_labels_seq.npy'), new_labels)

# %%
# 32-frame
data = np.load(os.path.join(data_dir, 'STMNIST', 'test', f'stmnistvideo_32f_test_data_seq.npy'))
labels = np.load(os.path.join(data_dir, 'STMNIST', 'test', f'stmnistvideo_32f_test_labels_seq.npy'))
new_data = data[samples]
new_labels = labels[samples]
np.save(os.path.join(data_dir, 'verification', 'STMNIST', 'stmnistvideo_32f_test_data_seq.npy'), new_data)
np.save(os.path.join(data_dir, 'verification', 'STMNIST', 'stmnistvideo_32f_test_labels_seq.npy'), new_labels)

# %%
# 64-frame
data = np.load(os.path.join(data_dir, 'STMNIST', 'test', f'stmnistvideo_64f_test_data_seq.npy'))
labels = np.load(os.path.join(data_dir, 'STMNIST', 'test', f'stmnistvideo_64f_test_labels_seq.npy'))
new_data = data[samples]
new_labels = labels[samples]
np.save(os.path.join(data_dir, 'verification', 'STMNIST', 'stmnistvideo_64f_test_data_seq.npy'), new_data)
np.save(os.path.join(data_dir, 'verification', 'STMNIST', 'stmnistvideo_64f_test_labels_seq.npy'), new_labels)
